# %% [markdown]
# # L4: Fallbacks with Branching Pipelines

# %% [markdown]
# <p style="background-color:#fff6e4; padding:15px; border-width:3px; border-color:#f5ecda; border-style:solid; border-radius:6px"> ⏳ <b>Note <code>(Kernel Starting)</code>:</b> This notebook takes about 30 seconds to be ready to use. You may start and watch the video while you wait.</p>

# %%
import warnings
from helper import load_env

warnings.filterwarnings('ignore')
load_env()

# %%
from haystack import Pipeline, Document
from haystack.components.routers import ConditionalRouter
from haystack.components.builders.prompt_builder import PromptBuilder
from haystack.components.generators import OpenAIGenerator
from haystack.components.retrievers.in_memory import InMemoryBM25Retriever
from haystack.components.websearch.serper_dev import SerperDevWebSearch
from haystack.document_stores.in_memory import InMemoryDocumentStore

# %% [markdown]
# <p style="background-color:#fff6ff; padding:15px; border-width:3px; border-color:#efe6ef; border-style:solid; border-radius:6px"> 💻 &nbsp; <b>Access <code>requirements.txt</code> and <code>helper.py</code> files:</b> 1) click on the <em>"File"</em> option on the top menu of the notebook and then 2) click on <em>"Open"</em>. For more help, please see the <em>"Appendix - Tips and Help"</em> Lesson.</p>

# %% [markdown]
# ### Index Documents into InMemoryDocumentStore

# %%
documents = [Document(content="Retrievers: Retrieves relevant documents to a user query using keyword search or semantic search."),
             Document(content="Embedders: Creates embeddings for text or documents."),
             Document(content="Generators: Use a number of model providers to generate answers or content based on a prompt"),
             Document(content="File Converters: Converts different file types like TXT, Markdown, PDF, etc. into a Haystack Document type")]

document_store = InMemoryDocumentStore()
document_store.write_documents(documents=documents)
# Out:
# 4

# %% [markdown]
# ### Create RAG Pipeline

# %%
rag_prompt_template = """
Answer the following query given the documents.
If the answer is not contained within the documents, reply with 'no_answer'
Query: {{query}}
Documents:
{% for document in documents %}
  {{document.content}}
{% endfor %}
"""

# %%
rag = Pipeline()
rag.add_component("retriever", InMemoryBM25Retriever(document_store=document_store))
rag.add_component("prompt_builder", PromptBuilder(template=rag_prompt_template))
rag.add_component("llm", OpenAIGenerator())

rag.connect("retriever.documents", "prompt_builder.documents")
rag.connect("prompt_builder", "llm")
# Out:
# <haystack.core.pipeline.pipeline.Pipeline object at 0x7fd9ae11fe10>
# 🚅 Components
#   - retriever: InMemoryBM25Retriever
#   - prompt_builder: PromptBuilder
#   - llm: OpenAIGenerator
# 🛤️ Connections
#   - retriever.documents -> prompt_builder.documents (List[Document])
#   - prompt_builder.prompt -> llm.prompt (str)

# %%
rag.show()

# %%
query = "What is a retriever for?"

rag.run({"prompt_builder":{"query": query},
         "retriever": {"query": query}})
# Out:
# {'llm': {'replies': ['Retrievers are used to retrieve relevant documents to a user query using keyword search or semantic search.'],
#   'meta': [{'model': 'gpt-3.5-turbo-0125',
#     'index': 0,
#     'finish_reason': 'stop',
#     'usage': {'completion_tokens': 20,
#      'prompt_tokens': 117,
#      'total_tokens': 137,
#      'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0},
#      'completion_tokens_details': {'reasoning_tokens': 0,
#       'audio_tokens': 0,
#       'accepted_prediction_tokens': 0,
#       'rejected_prediction_tokens': 0}}}]}}

# %%
query = "What Mistral components are there?"

rag.run({"prompt_builder":{"query": query},
         "retriever": {"query": query}})
# Out:
# {'llm': {'replies': ['no_answer'],
#   'meta': [{'model': 'gpt-3.5-turbo-0125',
#     'index': 0,
#     'finish_reason': 'stop',
#     'usage': {'completion_tokens': 2,
#      'prompt_tokens': 43,
#      'total_tokens': 45,
#      'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0},
#      'completion_tokens_details': {'reasoning_tokens': 0,
#       'audio_tokens': 0,
#       'accepted_prediction_tokens': 0,
#       'rejected_prediction_tokens': 0}}}]}}

# %% [markdown]
# ### Create Conditional Routes

# %% [markdown]
# Now that you got the model to respond with an answer or `no_answer`, you can create pipeline branches that are activated according to this response using the [`ConditionalRouter`](https://docs.haystack.deepset.ai/docs/conditionalrouter?utm_campaign=developer-relations&utm_source=dlai) component for this.

# %%
routes = [
    {
        "condition": "{{'no_answer' in replies[0]|lower}}",
        "output": "{{query}}",
        "output_name": "go_to_websearch",
        "output_type": str,
    },
    {
        "condition": "{{'no_answer' not in replies[0]|lower}}",
        "output": "{{replies[0]}}",
        "output_name": "answer",
        "output_type": str,
    },
]

# %%
router = ConditionalRouter(routes=routes)
router.run(replies=['Geoff is my friend'], query="Who is Geoff?")
# Out:
# {'answer': 'Geoff is my friend'}

# %%
router.run(replies=['No_answer'], query="Who is Geoff?")
# Out:
# {'go_to_websearch': 'Who is Geoff?'}

# %%
rag.add_component("router", ConditionalRouter(routes=routes))
rag.connect("llm.replies", "router.replies")

rag.show()

# %%
query = "What Mistral components does Haystack have?"

rag.run({"prompt_builder":{"query": query},
         "retriever": {"query": query},
         "router": {"query": query}})
# Out:
# {'llm': {'meta': [{'model': 'gpt-3.5-turbo-0125',
#     'index': 0,
#     'finish_reason': 'stop',
#     'usage': {'completion_tokens': 2,
#      'prompt_tokens': 119,
#      'total_tokens': 121,
#      'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0},
#      'completion_tokens_details': {'reasoning_tokens': 0,
#       'audio_tokens': 0,
#       'accepted_prediction_tokens': 0,
#       'rejected_prediction_tokens': 0}}}]},
#  'router': {'go_to_websearch': 'What Mistral components does Haystack have?'}}

# %% [markdown]
# ### Create Websearch Branch

# %%
prompt_for_websearch = """
Answer the following query given the documents retrieved from the web.
Your answer should indicate that your answer was generated from websearch.
You can also reference the URLs that the answer was generated from

Query: {{query}}
Documents:
{% for document in documents %}
  {{document.content}}
{% endfor %}
"""

# %% [markdown]
# ### Build a Pipeline with Conditional Routes

# %%
rag_or_websearch = Pipeline()
rag_or_websearch.add_component("retriever", InMemoryBM25Retriever(document_store=document_store))
rag_or_websearch.add_component("prompt_builder", PromptBuilder(template=rag_prompt_template))
rag_or_websearch.add_component("llm", OpenAIGenerator())
rag_or_websearch.add_component("router", ConditionalRouter(routes))
rag_or_websearch.add_component("websearch", SerperDevWebSearch())
rag_or_websearch.add_component("prompt_builder_for_websearch", PromptBuilder(template=prompt_for_websearch))
rag_or_websearch.add_component("llm_for_websearch",  OpenAIGenerator())

rag_or_websearch.connect("retriever", "prompt_builder.documents")
rag_or_websearch.connect("prompt_builder", "llm")
rag_or_websearch.connect("llm.replies", "router.replies")
rag_or_websearch.connect("router.go_to_websearch", "websearch.query")
rag_or_websearch.connect("router.go_to_websearch", "prompt_builder_for_websearch.query")
rag_or_websearch.connect("websearch.documents", "prompt_builder_for_websearch.documents")
rag_or_websearch.connect("prompt_builder_for_websearch", "llm_for_websearch")

rag_or_websearch.show()

# %%
query= "What is a retriever for?"

rag_or_websearch.run({"prompt_builder":{"query": query},
                      "retriever": {"query": query},
                      "router": {"query": query}})
# Out:
# {'llm': {'meta': [{'model': 'gpt-3.5-turbo-0125',
#     'index': 0,
#     'finish_reason': 'stop',
#     'usage': {'completion_tokens': 20,
#      'prompt_tokens': 117,
#      'total_tokens': 137,
#      'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0},
#      'completion_tokens_details': {'reasoning_tokens': 0,
#       'audio_tokens': 0,
#       'accepted_prediction_tokens': 0,
#       'rejected_prediction_tokens': 0}}}]},
#  'router': {'answer': 'Retrievers are used to retrieve relevant documents to a user query using keyword search or semantic search.'}}

# %%
query = "What Mistral components does Haystack have?"

rag_or_websearch.run({"prompt_builder":{"query": query},
                      "retriever": {"query": query},
                      "router": {"query": query}})
# Out:
# {'llm': {'meta': [{'model': 'gpt-3.5-turbo-0125',
#     'index': 0,
#     'finish_reason': 'stop',
#     'usage': {'completion_tokens': 2,
#      'prompt_tokens': 119,
#      'total_tokens': 121,
#      'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0},
#      'completion_tokens_details': {'reasoning_tokens': 0,
#       'audio_tokens': 0,
#       'accepted_prediction_tokens': 0,
#       'rejected_prediction_tokens': 0}}}]},
#  'websearch': {'links': ['https://haystack.deepset.ai/integrations/mistral',
#    'https://docs.haystack.deepset.ai/reference/integrations-mistral',
#    'https://www.e2enetworks.com/blog/rag-implementation-using-mistral-7b-haystack-and-weaviate',
#    'https://zilliz.com/tutorials/rag/haystack-and-milvus-and-mistral-7b-and-ollama-bge-m3',
#    'https://medium.com/mitb-for-all/a-gentle-introduction-to-the-llm-multiverse-part-2-haystack-c6af2548df04',
#    'https://zilliz.com/tutorials/rag/haystack-and-haystack-in-memory-store-and-mistral-small-and-mistral-embed',
#    'https://www.youtube.com/watch?v=C5mqILmVUEo',
#    'https://www.youtube.com/watch?v=01_2-Dy57ys',
#    'https://www.youtube.com/watch?v=5topvo0a4uY',
#    'https://www.youtube.com/watch?v=WhSbuGEbAR0']},
#  'llm_for_websearch': {'replies': ['Based on the documents retrieved from the web, Mistral components that Haystack has include the MistralDocumentEmbedder for computing Document embeddings using Mistral models. Additionally, Mistral 7B, a powerful language model, is mentioned in conjunction with Haystack for NLP tasks. The documents also refer to building a simple RAG chatbot in Python using Haystack, Mistral Small, and Mistral Embed. Furthermore, the tutorial demonstrates implementing the cutting-edge RAG model using Mistral 7B and Haystack. \n\nPlease note that this information was generated from a web search, and additional details may be available on the original websites.'],
#   'meta': [{'model': 'gpt-3.5-turbo-0125',
#     'index': 0,
#     'finish_reason': 'stop',
#     'usage': {'completion_tokens': 130,
#      'prompt_tokens': 369,
#      'total_tokens': 499,
#      'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0},
#      'completion_tokens_details': {'reasoning_tokens': 0,
#       'audio_tokens': 0,
#       'accepted_prediction_tokens': 0,
#       'rejected_prediction_tokens': 0}}}]}}

# %% [markdown]
# **Next:** Try out the following questions:
#
# - "Who is the president of the USA?"
# - "How should I initialize a generator with a Mistral model with Haystack?"
# - "What is the capital of France?"

# %%
query = "Who is the president of the USA?"

rag_or_websearch.run({"prompt_builder":{"query": query},
                      "retriever": {"query": query},
                      "router": {"query": query}})
# Out:
# {'llm': {'meta': [{'model': 'gpt-3.5-turbo-0125',
#     'index': 0,
#     'finish_reason': 'stop',
#     'usage': {'completion_tokens': 2,
#      'prompt_tokens': 118,
#      'total_tokens': 120,
#      'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0},
#      'completion_tokens_details': {'reasoning_tokens': 0,
#       'audio_tokens': 0,
#       'accepted_prediction_tokens': 0,
#       'rejected_prediction_tokens': 0}}}]},
#  'websearch': {'links': ['https://en.wikipedia.org/wiki/President_of_the_United_States',
#    'https://www.whitehouse.gov/administration/donald-j-trump/',
#    'https://www.whitehouse.gov/',
#    'https://trumpwhitehouse.archives.gov/people/donald-j-trump/',
#    'https://www.ohiosos.gov/elections/election-results-and-data/historical-election-comparisons/presidents-of-the-united-states-of-america/',
#    'https://www.usa.gov/presidents',
#    'https://x.com/potus',
#    'https://www.facebook.com/POTUS/',
#    'https://www.instagram.com/potus/?hl=en',
#    'https://en.wikipedia.org/wiki/Donald_Trump']},
#  'llm_for_websearch': {'replies': ['Based on the information retrieved from the web, the current president of the USA is Donald Trump. This information is gathered from various websites such as Wikipedia, social media pages, and news articles. (URLs: wikipedia.org, twitter.com, facebook.com)'],
#   'meta': [{'model': 'gpt-3.5-turbo-0125',
#     'index': 0,
#     'finish_reason': 'stop',
#     'usage': {'completion_tokens': 51,
#      'prompt_tokens': 397,
#      'total_tokens': 448,
#      'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0},
#      'completion_tokens_details': {'reasoning_tokens': 0,
#       'audio_tokens': 0,
#       'accepted_prediction_tokens': 0,
#       'rejected_prediction_tokens': 0}}}]}}

# %%
query = "What is the Financial Capital of India?"

rag_or_websearch.run({"prompt_builder":{"query": query},
                      "retriever": {"query": query},
                      "router": {"query": query}})
# Out:
# {'llm': {'meta': [{'model': 'gpt-3.5-turbo-0125',
#     'index': 0,
#     'finish_reason': 'stop',
#     'usage': {'completion_tokens': 2,
#      'prompt_tokens': 118,
#      'total_tokens': 120,
#      'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0},
#      'completion_tokens_details': {'reasoning_tokens': 0,
#       'audio_tokens': 0,
#       'accepted_prediction_tokens': 0,
#       'rejected_prediction_tokens': 0}}}]},
#  'websearch': {'links': ['https://en.wikipedia.org/wiki/Mumbai',
#    'https://www.reddit.com/r/mumbai/comments/1d1vfdm/mumbai_so_called_financial_capital_is_the_3rd/',
#    'https://www.linkedin.com/pulse/why-mumbai-emerged-indias-financial-capital-global-lessons-abhas-jha-bu6fc',
#    'https://testbook.com/question-answer/which-city-is-known-as-financial-capital-of-india--63afbacca6b45ecae551cfd6',
#    'https://m.economictimes.com/news/india/indias-6-biggest-cities-you-should-know-about/mumbai-the-financial-capital-of-india/slideshow/120790553.cms',
#    'https://www.instagram.com/reel/C-NREr_KJG1/?hl=en',
#    'https://www.msn.com/en-za/news/other/mumbai-the-financial-capital-of-india/vi-AA1KFtSt',
#    'https://www.atlas.org/solution/b3758be4-6052-4c87-8c38-090a338945fe/which-city-is-known-as-the-financial-capital-of-india',
#    'https://www.youtube.com/watch?v=N7DvzLc78Nc',
#    'https://www.pajasaapartments.com/blog/mumbai-financial-capital-of-india/']},
#  'llm_for_websearch': {'replies': ["According to the information retrieved from various sources on the web, the financial capital of India is Mumbai. Mumbai is known as the financial, commercial, and entertainment capital of India. It is home to major financial institutions such as the Reserve Bank of India, Bombay Stock Exchange, and National Stock Exchange. The city's journey from a colonial outpost to becoming India's financial powerhouse is attributed to strategic investments, inclusivity, and resilience. Source URLs: (URL1, URL2, URL3, URL4, URL5)"],
#   'meta': [{'model': 'gpt-3.5-turbo-0125',
#     'index': 0,
#     'finish_reason': 'stop',
#     'usage': {'completion_tokens': 104,
#      'prompt_tokens': 361,
#      'total_tokens': 465,
#      'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0},
#      'completion_tokens_details': {'reasoning_tokens': 0,
#       'audio_tokens': 0,
#       'accepted_prediction_tokens': 0,
#       'rejected_prediction_tokens': 0}}}]}}

# %%
query = "Do you know who is sdivyanshu90 github, url: https://github.com/sdivyanshu90?"

rag_or_websearch.run({"prompt_builder":{"query": query},
                      "retriever": {"query": query},
                      "router": {"query": query}})
# Out:
# {'llm': {'meta': [{'model': 'gpt-3.5-turbo-0125',
#     'index': 0,
#     'finish_reason': 'stop',
#     'usage': {'completion_tokens': 2,
#      'prompt_tokens': 62,
#      'total_tokens': 64,
#      'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0},
#      'completion_tokens_details': {'reasoning_tokens': 0,
#       'audio_tokens': 0,
#       'accepted_prediction_tokens': 0,
#       'rejected_prediction_tokens': 0}}}]},
#  'websearch': {'links': ['https://github.com/sdivyanshu90',
#    'https://github.com/features/code-search',
#    'https://docs.github.com/en/get-started/git-basics/set-up-git',
#    'https://docs.github.com/en/get-started/exploring-projects-on-github/contributing-to-a-project',
#    'https://pages.github.com/',
#    'https://docs.github.com/en/repositories/creating-and-managing-repositories/creating-a-new-repository',
#    'https://www.theserverside.com/blog/Coffee-Talk-Java-News-Stories-and-Opinions/GitHub-URL-find-use-example',
#    'https://docs.github.com/',
#    'https://docs.github.com/en/get-started/exploring-projects-on-github/saving-repositories-with-stars',
#    'https://docs.github.com/en/authentication/keeping-your-account-and-data-secure/removing-sensitive-data-from-a-repository']},
#  'llm_for_websearch': {'replies': ['Based on the documents retrieved from the web, sdivyanshu90 on GitHub is someone who has coursework, assignments, and projects from the Deep Learning Specialization by Andrew Ng on Coursera in their repository (https://github.com/sdivyanshu90). This information was generated from websearch.'],
#   'meta': [{'model': 'gpt-3.5-turbo-0125',
#     'index': 0,
#     'finish_reason': 'stop',
#     'usage': {'completion_tokens': 63,
#      'prompt_tokens': 357,
#      'total_tokens': 420,
#      'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0},
#      'completion_tokens_details': {'reasoning_tokens': 0,
#       'audio_tokens': 0,
#       'accepted_prediction_tokens': 0,
#       'rejected_prediction_tokens': 0}}}]}}
